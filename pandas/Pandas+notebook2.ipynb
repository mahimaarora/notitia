# %%
import pandas as pd
movies = pd.read_csv('movie.csv', sep=',')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filter = movies['movieId'] % 2 == 0
filter.all()
# Out:
# False

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags = pd.read_csv('tag.csv', sep=',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c5b742354bde> in <module>()
# ----> 1 tags = pd.read_csv('tag.csv', sep=',')
#
# NameError: name 'pd' is not defined

# %%
tags.isnull().any()
# Out:
# userId       False
# movieId      False
# tag           True
# timestamp    False
# dtype: bool

# %%
tags = tags.dropna()

# %%
tags.isnull().any()
# Out:
# userId       False
# movieId      False
# tag          False
# timestamp    False
# dtype: bool

# %%
# %matplotlib inline
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
ratings = pd.read_csv('./Downloads/movielens/rating.csv', sep=',')

# %%
ratings.head()
# Out:
#    userId  movieId  rating         timestamp
# 0     1.0      2.0     3.5  02/04/2005 23:53
# 1     1.0     29.0     3.5  02/04/2005 23:31
# 2     1.0     32.0     3.5  02/04/2005 23:33
# 3     1.0     47.0     3.5  02/04/2005 23:32
# 4     1.0     50.0     3.5  02/04/2005 23:29

# %%
ratings.hist(column = 'rating', figsize = (15, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B872368CC0>]], dtype=object)

# %%
ratings.boxplot(column='rating', figsize= (15, 20))

# %%
import pandas as pd
tags = pd.read_csv('tag.csv', sep=',')
movies = pd.read_csv('movie.csv', sep=',')
ratings = pd.read_csv('./Downloads/movielens/rating.csv', sep=',')

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies[['title',  'genres' ]].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[1000:1010]
# Out:
#       userId  movieId  rating         timestamp
# 1000    11.0    531.0     4.5  01/01/2009 04:02
# 1001    11.0    541.0     4.5  01/01/2009 05:25
# 1002    11.0    546.0     5.0  01/01/2009 05:48
# 1003    11.0    551.0     5.0  01/01/2009 23:52
# 1004    11.0    586.0     4.0  02/01/2009 01:17
# 1005    11.0    587.0     4.5  02/01/2009 01:16
# 1006    11.0    588.0     5.0  25/08/2009 03:27
# 1007    11.0    589.0     4.5  01/01/2009 05:47
# 1008    11.0    592.0     4.5  01/01/2009 05:57
# 1009    11.0    593.0     5.0  02/01/2009 01:13

# %%
ratings[:10]
# Out:
#    userId  movieId  rating         timestamp
# 0     1.0      2.0     3.5  02/04/2005 23:53
# 1     1.0     29.0     3.5  02/04/2005 23:31
# 2     1.0     32.0     3.5  02/04/2005 23:33
# 3     1.0     47.0     3.5  02/04/2005 23:32
# 4     1.0     50.0     3.5  02/04/2005 23:29
# 5     1.0    112.0     3.5  10/09/2004 03:09
# 6     1.0    151.0     4.0  10/09/2004 03:08
# 7     1.0    223.0     4.0  02/04/2005 23:46
# 8     1.0    253.0     4.0  02/04/2005 23:35
# 9     1.0    260.0     4.0  02/04/2005 23:33

# %%
ratings[:-10]
# Out:
#          userId  movieId  rating         timestamp
# 0           1.0      2.0     3.5  02/04/2005 23:53
# 1           1.0     29.0     3.5  02/04/2005 23:31
# 2           1.0     32.0     3.5  02/04/2005 23:33
# 3           1.0     47.0     3.5  02/04/2005 23:32
# 4           1.0     50.0     3.5  02/04/2005 23:29
# 5           1.0    112.0     3.5  10/09/2004 03:09
# 6           1.0    151.0     4.0  10/09/2004 03:08
# 7           1.0    223.0     4.0  02/04/2005 23:46
# 8           1.0    253.0     4.0  02/04/2005 23:35
# 9           1.0    260.0     4.0  02/04/2005 23:33
# 10          1.0    293.0     4.0  02/04/2005 23:31
# 11          1.0    296.0     4.0  02/04/2005 23:32
# 12          1.0    318.0     4.0  02/04/2005 23:33
# 13          1.0    337.0     3.5  10/09/2004 03:08
# 14          1.0    367.0     3.5  02/04/2005 23:53
# 15          1.0    541.0     4.0  02/04/2005 23:30
# 16          1.0    589.0     3.5  02/04/2005 23:45
# ...

# %%
ratings[-10:]
# Out:
#          userId  movieId  rating timestamp
# 1048563     NaN      NaN     NaN       NaN
# 1048564     NaN      NaN     NaN       NaN
# 1048565     NaN      NaN     NaN       NaN
# 1048566     NaN      NaN     NaN       NaN
# 1048567     NaN      NaN     NaN       NaN
# 1048568     NaN      NaN     NaN       NaN
# 1048569     NaN      NaN     NaN       NaN
# 1048570     NaN      NaN     NaN       NaN
# 1048571     NaN      NaN     NaN       NaN
# 1048572     NaN      NaN     NaN       NaN

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[:13]
# Out:
# sci-fi             3384
# based on a book    3281
# atmospheric        2917
# comedy             2779
# action             2657
# surreal            2427
# BD-R               2334
# twist ending       2323
# funny              2072
# dystopia           1991
# stylized           1941
# quirky             1906
# dark comedy        1899
# Name: tag, dtype: int64

# %%
tags.head(10)
# Out:
#    userId  movieId               tag            timestamp
# 0      18     4141       Mark Waters  2009-04-24 18:19:40
# 1      65      208         dark hero  2013-05-10 01:41:18
# 2      65      353         dark hero  2013-05-10 01:41:19
# 3      65      521     noir thriller  2013-05-10 01:39:43
# 4      65      592         dark hero  2013-05-10 01:41:18
# 5      65      668         bollywood  2013-05-10 01:37:56
# 6      65      898  screwball comedy  2013-05-10 01:42:40
# 7      65     1248     noir thriller  2013-05-10 01:39:43
# 8      65     1391              mars  2013-05-10 01:40:55
# 9      65     1617          neo-noir  2013-05-10 01:43:37

# %%
# %matplotlib inline
tag_counts[:10].plot(kind='bar', figsize=(15, 10))

# %%
is_highly_rated = ratings['rating'] >= 4.0
ratings[is_highly_rated][-5:]
# Out:
#          userId  movieId  rating         timestamp
# 1046644  7101.0  58559.0     4.5  17/09/2009 01:46
# 1046645  7101.0  68159.0     4.5  17/09/2009 02:00
# 1046646  7101.0  69481.0     4.5  17/09/2009 02:01
# 1046650  7102.0     22.0     4.0  15/11/2005 11:50
# 1046651  7102.0     29.0     4.5  15/11/2005 11:50

# %%
ratings[is_highly_rated][30:50]
# Out:
#      userId  movieId  rating         timestamp
# 68      1.0   2021.0     4.0  02/04/2005 23:52
# 69      1.0   2100.0     4.0  02/04/2005 23:52
# 70      1.0   2118.0     4.0  10/09/2004 03:14
# 71      1.0   2138.0     4.0  02/04/2005 23:49
# 72      1.0   2140.0     4.0  02/04/2005 23:48
# 73      1.0   2143.0     4.0  02/04/2005 23:52
# 74      1.0   2173.0     4.0  02/04/2005 23:51
# 75      1.0   2174.0     4.0  02/04/2005 23:50
# 76      1.0   2193.0     4.0  02/04/2005 23:49
# 79      1.0   2288.0     4.0  10/09/2004 03:14
# 80      1.0   2291.0     4.0  10/09/2004 03:09
# 81      1.0   2542.0     4.0  02/04/2005 23:44
# 82      1.0   2628.0     4.0  02/04/2005 23:53
# 90      1.0   2762.0     4.0  02/04/2005 23:42
# 92      1.0   2872.0     4.0  02/04/2005 23:48
# 94      1.0   2944.0     4.0  02/04/2005 23:43
# 96      1.0   2959.0     4.0  10/09/2004 03:08
# 97      1.0   2968.0     4.0  02/04/2005 23:50
# 101     1.0   3081.0     4.0  10/09/2004 03:15
# ...

# %%
is_animation = movies['genres'].str.contains('Animation')
movies[is_animation][5:20]
# Out:
#      movieId                                       title  \
# 310      313                   Swan Princess, The (1994)
# 360      364                       Lion King, The (1994)
# 388      392  Secret Adventures of Tom Thumb, The (1993)
# 547      551      Nightmare Before Christmas, The (1993)
# 553      558                      Pagemaster, The (1994)
# 582      588                              Aladdin (1992)
# 588      594      Snow White and the Seven Dwarfs (1937)
# 589      595                 Beauty and the Beast (1991)
# 590      596                            Pinocchio (1940)
# 604      610                          Heavy Metal (1981)
# 610      616                      Aristocats, The (1970)
# 624      631              All Dogs Go to Heaven 2 (1996)
# 653      661            James and the Giant Peach (1996)
# 664      673                            Space Jam (1996)
# 697      709                     Oliver & Company (1988)
#
# ...

# %%
movies[is_animation].head()
# Out:
#      movieId                    title  \
# 0          1         Toy Story (1995)
# 12        13             Balto (1995)
# 47        48        Pocahontas (1995)
# 236      239    Goofy Movie, A (1995)
# 241      244  Gumby: The Movie (1995)
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 12                  Adventure|Animation|Children
# 47      Animation|Children|Drama|Musical|Romance
# 236            Animation|Children|Comedy|Romance
# 241                           Animation|Children

# %%
ratings_count = ratings[['movieId', 'rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5       13221
# 1.0       35103
# 1.5       14019
# 2.0       74621
# 2.5       44753
# 3.0      225752
# 3.5      112759
# 4.0      294554
# 4.5       79681
# 5.0      152194

# %%
avg_ratings_count = ratings[['movieId', 'rating']].groupby('movieId').mean()
avg_ratings_count
# Out:
#             rating
# movieId
# 1.0       3.958236
# 2.0       3.268229
# 3.0       3.185673
# 4.0       3.000000
# 5.0       3.141985
# 6.0       3.835322
# 7.0       3.381089
# 8.0       3.352564
# 9.0       3.027363
# 10.0      3.428479
# 11.0      3.708939
# 12.0      2.661692
# 13.0      3.237179
# 14.0      3.410876
# 15.0      2.710692
# 16.0      3.850521
# 17.0      3.950136
# 18.0      3.322344
# 19.0      2.586996
# 20.0      2.866029
# 21.0      3.626312
# 22.0      3.360853
# 23.0      3.165094
# 24.0      3.156840
# 25.0      3.702653
# 26.0      3.600000
# 27.0      3.313187
# 28.0      4.054545
# 29.0      4.002237
# 30.0      3.633929
# ...            ...
# 127323.0  2.500000
# 127881.0  3.000000
# 128356.0  1.500000
# 128358.0  3.000000
# 128488.0  2.000000
# 128510.0  3.000000
# 128520.0  4.000000
# 128594.0  0.500000
# 128601.0  2.500000
# 128622.0  3.000000
# 128648.0  2.000000
# 128686.0  3.000000
# 128715.0  4.000000
# 128736.0  1.000000
# 128832.0  4.500000
# ...

# %%
movie_count = ratings[['movieId', 'rating']].groupby('movieId').count()
movie_count.head()
# Out:
#          rating
# movieId
# 1.0        2562
# 2.0        1152
# 3.0         684
# 4.0         138
# 5.0         655

# %%
print(tags.head())
print()
print(movies.head())
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18
#
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = movies.merge(tags, on='movieId', how='inner')
t.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                                     tag            timestamp
# 0    1644                                 Watched  2014-12-04 23:44:40
# 1    1741                      computer animation  2007-07-08 13:59:15
# 2    1741                 Disney animated feature  2007-07-08 22:21:47
# 3    1741                         Pixar animation  2007-07-08 22:46:10
# 4    1741  TÃ©a Leoni does not star in this movie  2009-06-15 19:19:33

# %%
avg_ratings = ratings.groupby('movieId', as_index=False).mean()
del avg_ratings['userId']
avg_ratings.head()
# Out:
#    movieId    rating
# 0      1.0  3.958236
# 1      2.0  3.268229
# 2      3.0  3.185673
# 3      4.0  3.000000
# 4      5.0  3.141985

# %%
box_office = movies.merge(avg_ratings, on='movieId', how='inner')
box_office.tail()
# Out:
#       movieId                   title                           genres  rating
# 14020  130073       Cinderella (2015)  Adventure|Children|Drama|Sci-Fi    2.50
# 14021  130219  The Dark Knight (2011)      Action|Crime|Drama|Thriller    4.50
# 14022  130462          The Boy (2015)               (no genres listed)    4.00
# 14023  130490        Insurgent (2015)            Action|Romance|Sci-Fi    2.25
# 14024  130642      Backcountry (2014)            Drama|Horror|Thriller    3.00

# %%
is_highly_rated = box_office['rating'] >= 4.0
box_office[is_highly_rated][-5:]
# Out:
#       movieId                       title                        genres  \
# 14001  128520   The Wedding Ringer (2015)                        Comedy
# 14007  128715  Eloise at the Plaza (2003)       Children|Comedy|Mystery
# 14009  128832  The Last Five Years (2014)  Comedy|Drama|Musical|Romance
# 14021  130219      The Dark Knight (2011)   Action|Crime|Drama|Thriller
# 14022  130462              The Boy (2015)            (no genres listed)
#
#        rating
# 14001     4.0
# 14007     4.0
# 14009     4.5
# 14021     4.5
# 14022     4.0

# %%
is_comedy = box_office['genres'].str.contains('Comedy')
box_office[is_comedy]
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 6           7                                     Sabrina (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 17         18                                  Four Rooms (1995)
# 18         19              Ace Ventura: When Nature Calls (1995)
# 19         20                                 Money Train (1995)
# 20         21                                  Get Shorty (1995)
# 37         38                                It Takes Two (1995)
# 38         39                                    Clueless (1995)
# ...

# %%
box_office[is_comedy & is_highly_rated]
# Out:
#       movieId                                              title  \
# 226       232        Eat Drink Man Woman (Yin shi nan nu) (1994)
# 290       296                                Pulp Fiction (1994)
# 349       356                                Forrest Gump (1994)
# 595       608                                       Fargo (1996)
# 643       665                                 Underground (1995)
# 693       720  Wallace & Gromit: The Best of Aardman Animatio...
# 717       745             Wallace & Gromit: A Close Shave (1995)
# 722       750  Dr. Strangelove or: How I Learned to Stop Worr...
# 749       778                               Trainspotting (1996)
# 765       794                    Midnight Dancers (Sibak) (1994)
# 768       797  Old Lady Who Walked in the Sea, The (Vieille q...
# 822       856                             Mille bolle blu (1993)
# 835       871                                Lover's Knot (1996)
# ...

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie_genres = movies['genres'].str.split('|', expand=True)

# %%
movie_genres[:10]
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
# 5     Action      Crime  Thriller    None     None  None  None  None  None
# 6     Comedy    Romance      None    None     None  None  None  None  None
# 7  Adventure   Children      None    None     None  None  None  None  None
# 8     Action       None      None    None     None  None  None  None  None
# 9     Action  Adventure  Thriller    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None

# %%
movie_genres['isComedy'] = movies['genres'].str.contains('Comedy')
movie_genres[:10]
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
# 5     Action      Crime  Thriller    None     None  None  None  None  None
# 6     Comedy    Romance      None    None     None  None  None  None  None
# 7  Adventure   Children      None    None     None  None  None  None  None
# 8     Action       None      None    None     None  None  None  None  None
# 9     Action  Adventure  Thriller    None     None  None  None  None  None
#
#       9  isComedy
# 0  None      True
# 1  None     False
# 2  None      True
# 3  None      True
# 4  None      True
# 5  None     False
# ...

# %%
movies['year'] = movies['title'].str.extract('.*\((.*)\).*', expand=True)
movies.tail()
# Out:
#        movieId                          title                    genres  year
# 27273   131254   Kein Bund für's Leben (2007)                    Comedy  2007
# 27274   131256  Feuer, Eis & Dosenbier (2002)                    Comedy  2002
# 27275   131258             The Pirates (2014)                 Adventure  2014
# 27276   131260            Rentun Ruusu (2001)        (no genres listed)  2001
# 27277   131262               Innocence (2014)  Adventure|Fantasy|Horror  2014

# %%
tags.dtypes
# Out:
# userId        int64
# movieId       int64
# tag          object
# timestamp    object
# dtype: object

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tags = pd.read_csv('./Downloads/tags.csv', sep=',')
tags.dtypes
# Out:
# userId        int64
# movieId       int64
# tag          object
# timestamp     int64
# dtype: object

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
tags['parsed_time'] = pd.to_datetime(tags['timestamp'], unit='s')

# %%
tags['parsed_time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
tags.head(3)
# Out:
#    userId  movieId          tag   timestamp         parsed_time
# 0      18     4141  Mark Waters  1240597180 2009-04-24 18:19:40
# 1      65      208    dark hero  1368150078 2013-05-10 01:41:18
# 2      65      353    dark hero  1368150079 2013-05-10 01:41:19

# %%
greater_than_t = tags['parsed_time'] > '2015-02-01'
selected_rows =tags[greater_than_t]
tags.shape, selected_rows.shape
# Out:
# ((465564, 5), (12130, 5))

# %%
tags.sort_values(by='parsed_time', ascending=True)[:10]
# Out:
#         userId  movieId              tag   timestamp         parsed_time
# 333932  100371     2788     monty python  1135429210 2005-12-24 13:00:10
# 333927  100371     1732    coen brothers  1135429236 2005-12-24 13:00:36
# 333924  100371     1206  stanley kubrick  1135429248 2005-12-24 13:00:48
# 333923  100371     1193   jack nicholson  1135429371 2005-12-24 13:02:51
# 333939  100371     5004    peter sellers  1135429399 2005-12-24 13:03:19
# 333922  100371       47   morgan freeman  1135429412 2005-12-24 13:03:32
# 333921  100371       47        brad pitt  1135429412 2005-12-24 13:03:32
# 333936  100371     4011        brad pitt  1135429431 2005-12-24 13:03:51
# 333937  100371     4011      guy ritchie  1135429431 2005-12-24 13:03:51
# 333920  100371       32     bruce willis  1135429442 2005-12-24 13:04:02

# %%
avg_ratings_count = ratings[['movieId', 'rating']].groupby('movieId', as_index=False).mean()
avg_ratings_count[:5]
# Out:
#    movieId    rating
# 0      1.0  3.958236
# 1      2.0  3.268229
# 2      3.0  3.185673
# 3      4.0  3.000000
# 4      5.0  3.141985

# %%
joined = movies.merge(avg_ratings_count, on='movieId', how='inner')
joined.head()
joined.corr()
# Out:
#         rating
# rating     1.0

# %%
yearly_average = joined[['year', 'rating']].groupby('year', as_index=False).mean()
yearly_average[:5]
# Out:
#    year  rating
# 0  1898    4.00
# 1  1900    3.50
# 2  1902    3.70
# 3  1903    4.25
# 4  1909    1.50

# %%
# %matplotlib inline
yearly_average[-20:].plot(x='year',y='rating', figsize=(15,10), grid=True)
